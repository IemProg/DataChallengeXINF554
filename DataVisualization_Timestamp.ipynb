# %% [markdown]
# <a href="https://colab.research.google.com/github/IemProg/DataChallengeXINF554/blob/main/DataVisualization_Timestamp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Setting Up
# - import necessary libraries and install useful packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import os, sys
import string
from collections import Counter
import warnings
import random
import re
import seaborn as sns

# %%
# Loading some sklearn packaces for modelling.

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.metrics import f1_score, accuracy_score
from wordcloud import WordCloud, STOPWORDS

# %%
# Libraries for text preprocessing.

import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
# !pip install verstack
# Out:
# Collecting verstack
#   Downloading https://files.pythonhosted.org/packages/bc/7e/6319afad955211755557db0f30c31a6eddd6cefcc795fec1c27bbb1b5e31/verstack-0.3.1.tar.gz
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from verstack) (1.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from verstack) (1.18.5)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.6/dist-packages (from verstack) (0.90)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (from verstack) (0.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->verstack) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->verstack) (2.8.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from xgboost->verstack) (1.4.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn->verstack) (0.22.2.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->verstack) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn->verstack) (0.17.0)
# Building wheels for collected packages: verstack
#   Building wheel for verstack (setup.py) ... done
#   Created wheel for verstack: filename=verstack-0.3.1-cp36-none-any.whl size=14343 sha256=b0e53895809c03c665f20db2c69eeafa6c4e2e17d24947f42153581529f11141
#   Stored in directory: /root/.cache/pip/wheels/15/1b/58/10e59516150cea4d9b1dbacceb3bffcc0cfd2d166efabec2f6
# Successfully built verstack
# Installing collected packages: verstack
# Successfully installed verstack-0.3.1

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import mean_absolute_error
from verstack.stratified_continuous_split import scsplit

# %%
# Setting some options for general use.

stop = set(stopwords.words('english'))
plt.style.use('fivethirtyeight')
sns.set(font_scale=1.5)
pd.options.display.max_columns = 250
pd.options.display.max_rows = 250
warnings.filterwarnings('ignore')

# %%
#Setting seeds for consistent results.
seed_val = 42
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %% [markdown]
# ### Loading Data

# %% [markdown]
# #### Colab

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
path_data = "/content/gdrive/MyDrive/DataSets"
path_data_train = path_data + "/train.csv"
train = pd.read_csv(path_data_train)
train.columns
# Out:
# Index(['id', 'timestamp', 'retweet_count', 'user_verified',
#        'user_statuses_count', 'user_followers_count', 'user_friends_count',
#        'user_mentions', 'urls', 'hashtags', 'text'],
#       dtype='object')

# %% [markdown]
# #### PC

# %%
path = os.getcwd()

# %%
path_data_train = path + "\\covidChallenge\\data\\train.csv"
train = pd.read_csv(path_data_train)
train.columns

# %% [markdown]
# #### Data Insight

# %%
train.sample(5)
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 638928  638928  1588286477191              2           True
# 251092  251092  1588690368705              0          False
# 623344  623344  1588668283020              0          False
# 49564    49564  1588324965410             95          False
# 452862  452862  1588530835544              5          False
#
#         user_statuses_count  user_followers_count  user_friends_count  \
# 638928                83362                 14658                 145
# 251092                13800                  1495                 626
# 623344                10652                   251                  98
# 49564                  9225                230080                2421
# 452862                 3750                  4077                 623
#
#          user_mentions                         urls hashtags  \
# 638928             NaN  twitter.com/i/web/status/1…      NaN
# 251092             NaN                          NaN      NaN
# 623344             NaN                          NaN      NaN
# 49564              NaN                          NaN      NaN
# 452862  Matteo_Galizzi  twitter.com/i/web/status/1…  COVID19
#
#                                                      text
# 638928  People who love to cook and are looking for so...
# 251092  This 2020 is closed.\n\nKilo de gan. Who did e...
# 623344                 Could there be a pattern emerging?
# 49564   NEW: Brazil reports 6,276 new cases of coronav...
# 452862  What can we learn from the policy response to ...

# %%
print("\t Shape of training set is: ", train.shape)
# Out:
# 	 Shape of training set is:  (665777, 11)

# %% [markdown]
# #### Removing duplicates

# %%
train.drop_duplicates(subset='text', inplace=True)

# %%
print("\t Shape of training set is: ", train.shape)
# Out:
# 	 Shape of training set is:  (665777, 11)

# %% [markdown]
# **Comment:**
# > - It seems that we do not have duplicates in text column

# %% [markdown]
# ### Data Distribution

# %%
#Discretize into three equal-sized bins.
intervals = pd.cut(train['retweet_count'], 4, retbins=True)

# %%
intervals[1]
# Out:
# array([  -942.572, 235643.   , 471286.   , 706929.   , 942572.   ])

# %%
print(max(train['retweet_count']))
# Out:
# 942572

# %%
def calculate_nbr_bins(df, maxInt):
    counter = 0
    for i in df['retweet_count']:
        if i < maxInt:
            counter += 1
    return counter

# %%
calculate_nbr_bins(train, 235643)
# Out:
# 665766

# %%
# Displaying target distribution.

fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(18, 6), dpi=100)
sns.countplot(train['user_verified'], ax=axes[0])
axes[1].pie(train['user_verified'].value_counts(),
            labels=['Non-verified User', 'Verified User'],
            autopct='%1.2f%%',
            shadow=True,
            explode=(0.05, 0),
            startangle=60)
fig.suptitle('Distribution of the Users and Their Tweets', fontsize=24)
plt.show()

# %% [markdown]
# **Comment:**
#
# > - We can see that the dataset is clearly unbalanced with respect to user verified account.

# %% [markdown]
# ### Sorting According to Different Columns

# %%
sorted_followers = train.sort_values(by=['user_followers_count'], ascending = False)
sorted_followers.head(n=5)
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 308445  308445  1588709550016          37549           True
# 529350  529350  1588703408686          42851           True
# 241246  241246  1588702306684          37942           True
# 81059    81059  1588702322952          93528           True
# 40881    40881  1588702286963           6461           True
#
#         user_statuses_count  user_followers_count  user_friends_count  \
# 308445                15795             117064033              606798
# 529350                15795             117059317              606799
# 241246                15795             117058583              606797
# 81059                 15795             117058323              606799
# 40881                 15795             117058259              606799
#
#             user_mentions                         urls hashtags  \
# 308445                NaN  twitter.com/i/web/status/1…      NaN
# 529350          SenWarren  twitter.com/i/web/status/1…      NaN
# 241246                NaN  twitter.com/i/web/status/1…      NaN
# 81059                 NaN  twitter.com/i/web/status/1…      NaN
# 40881   rgay, SheaSerrano  twitter.com/i/web/status/1…      NaN
#
#                                                      text
# 308445  No one should be forced to choose between thei...
# 529350  As she often does, @SenWarren provides a cogen...
# 241246  We can't deny that racial and socioeconomic fa...
# 81059   We owe a profound debt of gratitude to all our...
# 40881   .@rgay and @SheaSerrano are using their feeds ...

# %%
sorted_retweets = train.sort_values(by=['retweet_count'], ascending = False)
sorted_retweets.head(n=5)
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 546442  546442  1588599747040         942572           True
# 565532  565532  1588287503976         647993           True
# 225845  225845  1588599467583         636394           True
# 117825  117825  1588305672852         415787          False
# 622524  622524  1588611150023         334427           True
#
#         user_statuses_count  user_followers_count  user_friends_count  \
# 546442                12256              25441659                 133
# 565532                11599              27641492                 824
# 225845                12256              25441494                 133
# 117825                 1956                 14783                1530
# 622524                 4622               5313436                  26
#
#        user_mentions urls hashtags  \
# 546442           NaN  NaN      NaN
# 565532           NaN  NaN      NaN
# 225845           NaN  NaN      NaN
# 117825           NaN  NaN      NaN
# 622524           NaN  NaN      NaN
#
#                                                      text
# 546442                Never Not 💜 https://t.co/Ag9oUTJvrN
# 565532  To all the little girls watching...never doubt...
# 225845                          ☺ https://t.co/9vNeJtA1vW
# 117825  Easily one of the best social distancing ads I...
# 622524  I can’t believe I have to say this, but please...

# %%
from datetime import datetime
column = train["timestamp"]
max_value_date = column.max()
min_value_date = column.min()
print("\t Earliest Tweet's Date: ", datetime.fromtimestamp(min_value_date / 1000))
print("\t Latest Tweet's Date: ", datetime.fromtimestamp(max_value_date / 1000))
# Out:
# 	 Earliest Tweet's Date:  2020-04-30 21:59:36.689000
# 	 Latest Tweet's Date:  2020-05-05 21:59:39.848000

# %%
sorted_retweets = train.sort_values(by=['timestamp'], ascending = False)
sorted_retweets.head(n=5)
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 631279  631279  1588715979848              0          False
# 582855  582855  1588715979248             11           True
# 562706  562706  1588715978117              8          False
# 655466  655466  1588715977915              1           True
# 298083  298083  1588715977830              2          False
#
#         user_statuses_count  user_followers_count  user_friends_count  \
# 631279                  616                   149                 233
# 582855                15619                 26263                3516
# 562706                 7232                   803                  24
# 655466               135231                171139                1407
# 298083                 1874                    86                 361
#
#        user_mentions                              urls hashtags  \
# 631279           NaN                               NaN      NaN
# 582855           ABC                   abcn.ws/35xdWsO      NaN
# 562706           NaN  malaysiaaktif.my/malaysiaaktif2…      NaN
# 655466           NaN       latimes.com/entertainment-…      NaN
# 298083           NaN                               NaN      NaN
#
#                                                      text
# 631279          Lab rats when we already know the outcome
# 582855  Trump to ABC's David Muir: 'Possible there wil...
# 562706  Pub, Restoran Jual Minuman Keras Tidak Dibenar...
# 655466  Disney parks take a $1 billion hit amid corona...
# 298083  Lies cost lives and people like him, Icke, Ger...

# %%
timestamp = 1588715977830
time = datetime.fromtimestamp(timestamp / 1000)
time.hour
# Out:
# 21

# %%
from datetime import datetime
datatime = []
for timestamp in train['timestamp']:
  time = datetime.fromtimestamp(timestamp / 1000)
  datatime.append(time)
train['data_time'] = datatime

# %%
from datetime import datetime
datatime = []
for timestamp in train['timestamp']:
  time = datetime.fromtimestamp(timestamp / 1000)
  datatime.append(time.hour)
train['time'] = datatime

# %%
train.head()
# Out:
#    id      timestamp  retweet_count  user_verified  user_statuses_count  \
# 0   0  1588696955143              0          False                68460
# 1   1  1588464948124              0          False                  309
# 2   2  1588634673360              0          False                 3241
# 3   3  1588433158672              0          False                32327
# 4   4  1588582751599              0          False                  581
#
#    user_followers_count  user_friends_count user_mentions urls hashtags  \
# 0                  1101                1226           NaN  NaN      NaN
# 1                    51                 202           NaN  NaN      NaN
# 503392                17402                  2757                 430
# 535135               142957                138422               11082
# 535541               102343                  2912                1509
# 546442                12256              25441659                 133
# 556503                27752                  5911                1841
# 556993                  778                 19125                  84
# 561557                 8497               3046999                1051
# 565532                11599              27641492                 824
# 566837                 1243                453844                 102
# 568007                 1196                  8645                 122
# 579912                 4096                 19690                7380
# 592212               111663                 27127                1334
# 596182                  841                  1851                 545
# 596549                14318                454065                  27
# 602427                48822                123612                 804
# 605256                18364                 13605                 766
# 618560                 9987                  9837                 428
# 622524                 4622               5313436                  26
# 637425                22519                 96401                7650
# 638579               328955                  2286                1328
# 660972                16397                 31574                1550
#
#        user_mentions                         urls  \
# 5750             NaN  twitter.com/i/web/status/1…
# 7357             NaN                          NaN
# 30557            NaN                          NaN
# 31017            NaN  twitter.com/i/web/status/1…
# 35507            NaN  twitter.com/i/web/status/1…
# 45699            NaN                          NaN
# 50242            NaN                          NaN
# 60523            NaN                          NaN
# 60577            NaN                          NaN
# 61201            NaN                          NaN
# 67926            NaN                          NaN
# 86180            NaN                          NaN
# 86760            NaN                          NaN
# 91091            NaN  twitter.com/i/web/status/1…
# 115891           NaN  twitter.com/i/web/status/1…
# 117825           NaN                          NaN
# 119322           NaN  twitter.com/i/web/status/1…
# 143257           NaN                          NaN
# 153971     MelBrooks                          NaN
# 157462           NaN  twitter.com/i/web/status/1…
# 191288           NaN                          NaN
# 197725           NaN                          NaN
# 210249           NaN                          NaN
# 211555           NaN  twitter.com/i/web/status/1…
# 224651           NaN                          NaN
# 225845           NaN                          NaN
# 228319           NaN  twitter.com/i/web/status/1…
# 228400           NaN                          NaN
# 231642           NaN                          NaN
# 252655           NaN                          NaN
# 275029           NaN                          NaN
# 277334           NaN                          NaN
# 280864           NaN                          NaN
# 288191           NaN                          NaN
# 290272           NaN  twitter.com/i/web/status/1…
# 303209           NaN  twitter.com/i/web/status/1…
# 313705           NaN  twitter.com/i/web/status/1…
# 321606           NaN                          NaN
# 327965           NaN  twitter.com/i/web/status/1…
# 331773           NaN  twitter.com/i/web/status/1…
# 334253           NaN                          NaN
# 340499           NaN  twitter.com/i/web/status/1…
# 360433           NaN  twitter.com/i/web/status/1…
# 384422           NaN                          NaN
# 394091           NaN                          NaN
# 401441           NaN  twitter.com/i/web/status/1…
# 408817           NaN                          NaN
# 416321           NaN                          NaN
# 417192           NaN  twitter.com/i/web/status/1…
# 419323           NaN                          NaN
# 428949           NaN                          NaN
# 430033           NaN                          NaN
# 436384           NaN                          NaN
# 441362           NaN  twitter.com/i/web/status/1…
# 459603           NaN  twitter.com/i/web/status/1…
# 465299           NaN                          NaN
# 469058           NaN  twitter.com/i/web/status/1…
# 470317           NaN                          NaN
# 471393           NaN  twitter.com/i/web/status/1…
# 477458           NaN                          NaN
# 485026           NaN                          NaN
# 486991           NaN                          NaN
# 492090           NaN  twitter.com/i/web/status/1…
# 495234           NaN  twitter.com/i/web/status/1…
# 497681           NaN  twitter.com/i/web/status/1…
# 498713           NaN                          NaN
# 503392           NaN  twitter.com/i/web/status/1…
# 535135           NaN                          NaN
# 535541           NaN  twitter.com/i/web/status/1…
# 546442           NaN                          NaN
# 556503           NaN  twitter.com/i/web/status/1…
# 556993           NaN  twitter.com/i/web/status/1…
# 561557     TeamPulte  twitter.com/i/web/status/1…
# 565532           NaN                          NaN
# 566837           NaN  twitter.com/i/web/status/1…
# 568007           NaN  twitter.com/i/web/status/1…
# 579912           NaN                          NaN
# 592212           NaN  twitter.com/i/web/status/1…
# 596182           NaN                          NaN
# 596549           NaN                          NaN
# 602427           NaN                          NaN
# 605256           NaN  twitter.com/i/web/status/1…
# 618560           NaN                          NaN
# 622524           NaN                          NaN
# 637425           NaN                          NaN
# 638579           NaN                          NaN
# 660972           NaN  twitter.com/i/web/status/1…
#
#                             hashtags  \
# 5750                             NaN
# 7357            BOTD, BTS_OF_THE_DAY
# 30557                            NaN
# 31017                            NaN
# 35507                            NaN
# 45699                            NaN
# 50242                            NaN
# 60523                            NaN
# 60577                            NaN
# 61201                            NaN
# 67926   COVID19, CoronavirusPandemic
# 86180                            NaN
# 86760                            NaN
# 91091                            NaN
# 115891                           NaN
# 117825                           NaN
# 119322                           NaN
# 143257                         JIMIN
# 153971  coronavirus, DontBeASpreader
# 157462                           NaN
# 191288                           NaN
# 197725                           NaN
# 210249                           NaN
# 211555                           NaN
# 224651                           NaN
# 225845                           NaN
# 228319                           NaN
# 228400                           NaN
# 231642                           NaN
# 252655                           NaN
# 275029                           NaN
# 277334                           NaN
# 280864                           NaN
# 288191                           NaN
# 290272                           NaN
# 303209                           NaN
# 313705                           NaN
# 321606                           NaN
# 327965                           NaN
# 331773                           NaN
# 334253                           NaN
# 340499                           NaN
# 360433                           NaN
# 384422                           NaN
# 394091                           NaN
# 401441                           NaN
# 408817                           NaN
# 416321                           NaN
# 417192                           NaN
# 419323                           NaN
# 428949                           NaN
# 430033                           NaN
# 436384                           NaN
# 441362                           NaN
# 459603                           NaN
# 465299                           NaN
# 469058                           NaN
# 470317                           NaN
# 471393                           NaN
# 477458                           NaN
# 485026                           NaN
# 486991                           NaN
# 492090                           NaN
# 495234                           NaN
# 497681                           NaN
# 498713                           NaN
# 503392                           NaN
# 535135                           NaN
# 535541                           NaN
# 546442                           NaN
# 556503                           NaN
# 556993                           NaN
# 561557                           NaN
# 565532                           NaN
# 566837                           NaN
# 568007                           NaN
# 579912                           NaN
# 592212                           NaN
# 596182                           NaN
# 596549                           NaN
# 602427                           NaN
# 605256                           NaN
# 618560                           NaN
# 622524                           NaN
# 637425                           NaN
# 638579                           NaN
# 660972                           NaN
#
#                                                      text  \
# 5750    Can y’all please just follow the government in...
# 7357    염색 했을 때 촬칵 !! \n우리 아미 머해요옹??\n\n #BOTD #BTS_OF...
# 30557   coronavirus seeing all the other terrible shit...
# 31017   The media: “CORONAVIRUS PANDEMIC IS GETTING WO...
# 35507   Coronavirus is everywhere. BOOK THAT FLIGHT. T...
# 45699   niggas saw that hockey could get canceled and ...
# 416321 2020-05-05 04:43:21.086     4
# 417192 2020-05-05 18:06:11.468    18
# 419323 2020-05-05 20:40:35.137    20
# 428949 2020-04-30 23:10:37.192    23
# 430033 2020-05-05 21:43:20.662    21
# 436384 2020-05-05 17:54:52.780    17
# 441362 2020-05-04 22:31:58.294    22
# 459603 2020-05-03 12:53:53.609    12
# 465299 2020-05-04 01:32:37.161     1
# 469058 2020-05-04 22:09:17.117    22
# 470317 2020-05-05 17:43:19.996    17
# 471393 2020-05-05 12:41:22.427    12
# 477458 2020-05-05 12:29:31.016    12
# 485026 2020-05-05 12:28:25.194    12
# 486991 2020-05-04 12:09:41.612    12
# 492090 2020-05-04 07:12:08.356     7
# 495234 2020-05-05 15:37:51.066    15
# 497681 2020-05-05 12:04:28.785    12
# 498713 2020-05-03 15:38:45.180    15
# 503392 2020-05-05 07:01:01.470     7
# 535135 2020-05-05 03:06:05.163     3
# 535541 2020-05-04 21:37:03.199    21
# 546442 2020-05-04 13:42:27.040    13
# 556503 2020-05-04 23:40:31.722    23
# 556993 2020-05-03 22:23:18.803    22
# 561557 2020-05-05 04:06:41.322     4
# 565532 2020-04-30 22:58:23.976    22
# 566837 2020-05-05 11:13:11.804    11
# 568007 2020-05-05 03:19:39.854     3
# 579912 2020-05-01 03:59:36.565     3
# 592212 2020-05-01 02:11:25.941     2
# 596182 2020-05-05 15:11:30.352    15
# 596549 2020-05-05 08:44:54.650     8
# 602427 2020-05-04 00:47:39.700     0
# 605256 2020-05-04 06:24:00.305     6
# 618560 2020-05-05 06:13:26.678     6
# 622524 2020-05-04 16:52:30.023    16
# 637425 2020-05-04 22:28:01.698    22
# 638579 2020-05-05 03:17:22.050     3
# 660972 2020-05-05 13:02:52.420    13

# %%
fig, ax = plt.subplots(1, 1, figsize=(25, 10))

ax.plot(new_data['retweet_count'], new_data["time"], 'go')
ax.set_title("Followers Count Versus Statuses")
ax.legend(loc='upper right', frameon=True)
# Out:
# No handles with labels found to put in legend.

# %%
def compute_dis(value):
  retweet_counter = 0
  tweet_counter = 0
  for index, row in train.iterrows():
    if (row['time'] == value):
      retweet_counter += row['retweet_count']
      tweet_counter += 1
  return tweet_counter, retweet_counter

# %%
retweets_time = []
tweets_time = []
i = 0 
while(i < 25):
  t, ret = compute_dis(i)
  print(t, ", ", ret)
  tweets_time.append(t)
  retweets_time.append(ret)
  i += 1
# Out:
# 28278 ,  4158691
# 26902 ,  4846907
# 24758 ,  3887591
# 23054 ,  4628084
# 20835 ,  5136960
# 19413 ,  3415876
# 19139 ,  4475698
# 19757 ,  3620998
# 20728 ,  3395772
# 20420 ,  3106974
# 21878 ,  3749082
# 25005 ,  3873663
# 27433 ,  3984137
# 30439 ,  5398395
# 31921 ,  4094804
# 32625 ,  4092960
# 34616 ,  4215618
# 34184 ,  4012219
# 34343 ,  3424610
# 32348 ,  3154302
# 32514 ,  3690855
# 31297 ,  3891423
# 38735 ,  5240136
# 35155 ,  4831118
# 0 ,  0

# %%
fig, ax = plt.subplots(1, 2, figsize=(25, 10))

ax[0].plot(retweets_time[0:24])
ax[1].plot(tweets_time[0:24])

plt.show()

# %% [markdown]
# **Comment:**
# > - Most the tweeters who has the biggest number of retweets does not have big number of followers, which means that it depends on other features such as the text (trendy topic maybe).

# %%
fig, ax = plt.subplots(2, 2, figsize=(25, 10))

ax[0, 0].plot(train["user_followers_count"], train['user_statuses_count'],'go')
ax[0, 0].set_title("Followers Count Versus Statuses")
ax[0, 0].legend(loc='upper right', frameon=True)

ax[0, 1].plot(train['user_followers_count'], train["user_friends_count"],'ro')
ax[0, 1].set_title("Followers Count Versus Users friend's")
ax[0, 1].legend(loc='upper right', frameon=True)

ax[1, 0].plot(train['user_followers_count'], train['retweet_count'],'bo')
ax[1, 0].set_title("Followers Count Versus Retweets")
ax[1, 0].legend(loc='upper right', frameon=True)

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
fig, ax = plt.subplots(2, 2, figsize=(25, 15))

ax[0, 0].plot(train["retweet_count"], train['user_statuses_count'],'go')
ax[0, 0].set_title("Retweets Versus Number of Statuses")
ax[0, 0].legend(loc='upper left', frameon=True)

ax[0, 1].plot(train['retweet_count'], train["user_friends_count"],'ro')
ax[0, 1].set_title("Retweets Versus Number of friends")
ax[0, 1].legend(loc='upper left', frameon=True)

ax[1, 0].plot(train['retweet_count'], train['user_followers_count'],'bo')
ax[1, 0].set_title("Retweets Versus Number of Followers")
ax[1, 0].legend(loc='upper left', frameon=True)

ax[1, 1].plot(train['retweet_count'], train['user_followers_count'], train['user_friends_count'], train['user_statuses_count'], 'bo')
ax[1, 1].set_title("Retweets Versus Number of Followers and Friends and Statuses")
ax[1, 1].legend(loc='upper left', frameon=True)

plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %% [markdown]
# **Comment:**
#
# > - We can see that the dataset is clearly unbalanced where most of the users has 0 re-tweets.

# %% [markdown]
# #### Undersampling
# - ???????????

# %%
# Shuffle the Dataset.
shuffled_train = train.sample(frac=1,random_state=4)

# Put all the samples where they dont have zeros re-tweet in a separate dataset.
non_zero_retweet = shuffled_train.loc[shuffled_train['retweet_count'] != 0]

#Randomly select 492 observations from the zero re-tweet (majority class)
zero_retweet = shuffled_train.loc[shuffled_train['retweet_count'] == 0].sample(n=492,random_state=42)

# Concatenate both dataframes again
normalized_train = pd.concat([non_zero_retweet, zero_retweet])

#plot the dataset after the undersampling
plt.figure(figsize=(12, 8))
sns.countplot('retweet_count', data=normalized_train)
plt.title('Balanced Classes')
plt.show()

# %%
normalized_train.shape
# Out:
# (243466, 11)

# %%
train
# Out:
#             id      timestamp  retweet_count  user_verified  \
# 0            0  1588696955143              0          False
# 1            1  1588464948124              0          False
# 2            2  1588634673360              0          False
# 3            3  1588433158672              0          False
# 4            4  1588582751599              0          False
# ...        ...            ...            ...            ...
# 665772  665772  1588412684317              0          False
# 665773  665773  1588324521711              1          False
# 665774  665774  1588353174952              8          False
# 665775  665775  1588691378352              0          False
# 665776  665776  1588432578764              0          False
#
#         user_statuses_count  user_followers_count  user_friends_count  \
# 0                     68460                  1101                1226
# 1                       309                    51                 202
# 2                      3241                  1675                2325
# 3                     32327                   667                 304
# 4                       581                    42                 127
# ...                     ...                   ...                 ...
# 665772                65355                  1984                1902
# 665773                 1807                  2029                 347
# 665774                  888                    85                 257
# 665775                  452                    38                  91
# 665776                  590                   184                 238
#
#        user_mentions                         urls hashtags  \
# 0                NaN                          NaN      NaN
# 1                NaN                          NaN      NaN
# 2                NaN                          NaN      NaN
# 3                NaN                          NaN      NaN
# 4                NaN                          NaN      NaN
# ...              ...                          ...      ...
# 665772           NaN                          NaN      NaN
# 665773  StanfordEMED  twitter.com/i/web/status/1…  COVID19
# 665774           NaN  twitter.com/i/web/status/1…      NaN
# 665775           NaN                          NaN      NaN
# 665776           NaN                          NaN      NaN
#
#                                                      text
# 0                                           Smh I give up
# 1       Most of us are Human Beings, but I think you m...
# 2       Old dirty tricks Trump, at it again...like we ...
# 3       Seriously..... I worked 86 hours my last check...
# 4       May ALMIGHTY ALLAH have mercy on us all. Only ...
# ...                                                   ...
# 665772                     18 months dawg? Come on man...
# 665773  Thank you to all of the nurses in our @Stanfor...
# 665774  'Post it' pearls for Palliative, End of Life a...
# 665775  His facial expressions are kind of looking for...
# 665776                              We really can't wait.
#
# [665777 rows x 11 columns]

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Cleaning Dataset
#
# In order to clean the dataset, what we have to:
# > 1- Removed urls, emojis, html tags and punctuations.
#
# > 2- Tokenized the tweet base texts.
#
# > 3- Lower cased clean text.
#
# > 4- Removed stopwords.
#
# > 5- Applied part of speech tags.
#
# > 6- Converted part of speeches to wordnet format.
#
# > 7- Applying word lemmatizer.
#
# > 8- Converted tokenized text to string again.

# %%
# Some basic helper functions to clean text by removing urls, emojis, html tags and punctuations.

def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)


def remove_emoji(text):
    emoji_pattern = re.compile(
        '['
        u'\U0001F600-\U0001F64F'  # emoticons
        u'\U0001F300-\U0001F5FF'  # symbols & pictographs
        u'\U0001F680-\U0001F6FF'  # transport & map symbols
        u'\U0001F1E0-\U0001F1FF'  # flags (iOS)
        u'\U00002702-\U000027B0'
        u'\U000024C2-\U0001F251'
        ']+',
        flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)


def remove_html(text):
    html = re.compile(r'<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    return re.sub(html, '', text)


def remove_punct(text):
    table = str.maketrans('', '', string.punctuation)
    return text.translate(table)

# %%
# Applying helper functions
train_clean = train.copy()
train_clean['text'] = train['text'].apply(lambda x: remove_URL(x))
train_clean['text'] = train['text'].apply(lambda x: remove_emoji(x))
train_clean['text'] = train['text'].apply(lambda x: remove_html(x))
train_clean['text'] = train['text'].apply(lambda x: remove_punct(x))

# %%
# Tokenizing the tweet base texts.

train_clean['tokenized'] = train_clean['text'].apply(word_tokenize)

train_clean.head()
# Out:
#    id      timestamp  retweet_count  user_verified  user_statuses_count  \
# 0   0  1588696955143              0          False                68460
# 1   1  1588464948124              0          False                  309
# 2   2  1588634673360              0          False                 3241
# 3   3  1588433158672              0          False                32327
# 4   4  1588582751599              0          False                  581
#
#    user_followers_count  user_friends_count user_mentions urls hashtags  \
# 0                  1101                1226           NaN  NaN      NaN
# 1                    51                 202           NaN  NaN      NaN
# 2                  1675                2325           NaN  NaN      NaN
# 3                   667                 304           NaN  NaN      NaN
# 4                    42                 127           NaN  NaN      NaN
#
#                                                 text  \
# 0                                      Smh I give up
# 1  Most of us are Human Beings but I think you mi...
# 2  Old dirty tricks Trump at it againlike we dont...
# 3  Seriously I worked 86 hours my last check and ...
# 4  May ALMIGHTY ALLAH have mercy on us all Only l...
#
#                                            tokenized
# 0                                 [Smh, I, give, up]
# 1  [Most, of, us, are, Human, Beings, but, I, thi...
# 2  [Old, dirty, tricks, Trump, at, it, againlike,...
# 3  [Seriously, I, worked, 86, hours, my, last, ch...
# 4  [May, ALMIGHTY, ALLAH, have, mercy, on, us, al...

# %%
# Lower casing clean text.

train_clean['lower'] = train_clean['tokenized'].apply(
    lambda x: [word.lower() for word in x])

train_clean.head()
# Out:
#    id      timestamp  retweet_count  user_verified  user_statuses_count  \
# 0   0  1588696955143              0          False                68460
# 1   1  1588464948124              0          False                  309
# 2   2  1588634673360              0          False                 3241
# 3   3  1588433158672              0          False                32327
# 4   4  1588582751599              0          False                  581
#
#    user_followers_count  user_friends_count user_mentions urls hashtags  \
# 0                  1101                1226           NaN  NaN      NaN
# 1                    51                 202           NaN  NaN      NaN
# 2                  1675                2325           NaN  NaN      NaN
# 3                   667                 304           NaN  NaN      NaN
# 4                    42                 127           NaN  NaN      NaN
#
#                                                 text  \
# 0                                      Smh I give up
# 1  Most of us are Human Beings but I think you mi...
# 2  Old dirty tricks Trump at it againlike we dont...
# 3  Seriously I worked 86 hours my last check and ...
# 4  May ALMIGHTY ALLAH have mercy on us all Only l...
#
#                                            tokenized  \
# 0                                 [Smh, I, give, up]
# 1  [Most, of, us, are, Human, Beings, but, I, thi...
# 2  [Old, dirty, tricks, Trump, at, it, againlike,...
# 3  [Seriously, I, worked, 86, hours, my, last, ch...
# 4  [May, ALMIGHTY, ALLAH, have, mercy, on, us, al...
#
#                                                lower
# 0                                 [smh, i, give, up]
# 1  [most, of, us, are, human, beings, but, i, thi...
# 2  [old, dirty, tricks, trump, at, it, againlike,...
# 3  [seriously, i, worked, 86, hours, my, last, ch...
# 4  [may, almighty, allah, have, mercy, on, us, al...

# %%
# Removing stopwords.

train_clean['stopwords_removed'] = train_clean['lower'].apply(
    lambda x: [word for word in x if word not in stop])

train_clean.head()
# Out:
#    id      timestamp  retweet_count  user_verified  user_statuses_count  \
# 0   0  1588696955143              0          False                68460
# 1   1  1588464948124              0          False                  309
# 2   2  1588634673360              0          False                 3241
# 3   3  1588433158672              0          False                32327
# 4   4  1588582751599              0          False                  581
#
#    user_followers_count  user_friends_count user_mentions urls hashtags  \
# 0                  1101                1226           NaN  NaN      NaN
# 1                    51                 202           NaN  NaN      NaN
# 2                  1675                2325           NaN  NaN      NaN
# 3                   667                 304           NaN  NaN      NaN
# 4                    42                 127           NaN  NaN      NaN
#
#                                                 text  \
# 0                                      Smh I give up
# 1  Most of us are Human Beings but I think you mi...
# 2  Old dirty tricks Trump at it againlike we dont...
# 3  Seriously I worked 86 hours my last check and ...
# 4  May ALMIGHTY ALLAH have mercy on us all Only l...
#
#                                            tokenized  \
# 0                                 [Smh, I, give, up]
# 1  [Most, of, us, are, Human, Beings, but, I, thi...
# 2  [Old, dirty, tricks, Trump, at, it, againlike,...
# 3  [Seriously, I, worked, 86, hours, my, last, ch...
# 4  [May, ALMIGHTY, ALLAH, have, mercy, on, us, al...
#
#                                                lower  \
# 0                                 [smh, i, give, up]
# 1  [most, of, us, are, human, beings, but, i, thi...
# 2  [old, dirty, tricks, trump, at, it, againlike,...
# 3  [seriously, i, worked, 86, hours, my, last, ch...
# 4  [may, almighty, allah, have, mercy, on, us, al...
#
#                                    stopwords_removed
# 0                                        [smh, give]
# 1     [us, human, beings, think, miss, boat, george]
# 2  [old, dirty, tricks, trump, againlike, dont, k...
# 3  [seriously, worked, 86, hours, last, check, ’,...
# 4  [may, almighty, allah, mercy, us, lagosians, o...

# %%
# Applying part of speech tags.

train_clean['pos_tags'] = train_clean['stopwords_removed'].apply(nltk.tag.pos_tag)

train_clean.head()
# Out:
#    id      timestamp  retweet_count  user_verified  user_statuses_count  \
# 0   0  1588696955143              0          False                68460
# 1   1  1588464948124              0          False                  309
# 2   2  1588634673360              0          False                 3241
# 3   3  1588433158672              0          False                32327
# 4   4  1588582751599              0          False                  581
#
#    user_followers_count  user_friends_count user_mentions urls hashtags  \
# 0                  1101                1226           NaN  NaN      NaN
# 1                    51                 202           NaN  NaN      NaN
# 2                  1675                2325           NaN  NaN      NaN
# 3                   667                 304           NaN  NaN      NaN
# 4                    42                 127           NaN  NaN      NaN
#
#                                                 text  \
# 0                                      Smh I give up
# 1  Most of us are Human Beings but I think you mi...
# 2  Old dirty tricks Trump at it againlike we dont...
# 3  Seriously I worked 86 hours my last check and ...
# 4  May ALMIGHTY ALLAH have mercy on us all Only l...
#
#                                            tokenized  \
# 0                                 [Smh, I, give, up]
# 1  [Most, of, us, are, Human, Beings, but, I, thi...
# 2  [Old, dirty, tricks, Trump, at, it, againlike,...
# 3  [Seriously, I, worked, 86, hours, my, last, ch...
# 4  [May, ALMIGHTY, ALLAH, have, mercy, on, us, al...
#
#                                                lower  \
# 0                                 [smh, i, give, up]
# 1  [most, of, us, are, human, beings, but, i, thi...
# 2  [old, dirty, tricks, trump, at, it, againlike,...
# 3  [seriously, i, worked, 86, hours, my, last, ch...
# 4  [may, almighty, allah, have, mercy, on, us, al...
#
#                                    stopwords_removed  \
# 0                                        [smh, give]
# 1     [us, human, beings, think, miss, boat, george]
# 2  [old, dirty, tricks, trump, againlike, dont, k...
# 3  [seriously, worked, 86, hours, last, check, ’,...
# 4  [may, almighty, allah, mercy, us, lagosians, o...
#
#                                             pos_tags
# 0                          [(smh, NNS), (give, VBP)]
# 1  [(us, PRP), (human, JJ), (beings, NNS), (think...
# 2  [(old, JJ), (dirty, NN), (tricks, NNS), (trump...
# 3  [(seriously, RB), (worked, VBD), (86, CD), (ho...
# 4  [(may, MD), (almighty, VB), (allah, NN), (merc...

# %%
# Converting part of speeches to wordnet format.

def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
train_clean['wordnet_pos'] = train_clean['pos_tags'].apply(
    lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])

train_clean.head()
# Out:
#    id      timestamp  retweet_count  user_verified  user_statuses_count  \
# 0   0  1588696955143              0          False                68460
# 1   1  1588464948124              0          False                  309
# 2   2  1588634673360              0          False                 3241
# 3   3  1588433158672              0          False                32327
# 4   4  1588582751599              0          False                  581
#
#    user_followers_count  user_friends_count user_mentions urls hashtags  \
# 0                  1101                1226           NaN  NaN      NaN
# 1                    51                 202           NaN  NaN      NaN
# 2                  1675                2325           NaN  NaN      NaN
# 3                   667                 304           NaN  NaN      NaN
# 4                    42                 127           NaN  NaN      NaN
#
#                                                 text  \
# 0                                      Smh I give up
# 1  Most of us are Human Beings but I think you mi...
# 2  Old dirty tricks Trump at it againlike we dont...
# 3  Seriously I worked 86 hours my last check and ...
# 4  May ALMIGHTY ALLAH have mercy on us all Only l...
#
#                                            tokenized  \
# 0                                 [Smh, I, give, up]
# 1  [Most, of, us, are, Human, Beings, but, I, thi...
# 2  [Old, dirty, tricks, Trump, at, it, againlike,...
# 3  [Seriously, I, worked, 86, hours, my, last, ch...
# 4  [May, ALMIGHTY, ALLAH, have, mercy, on, us, al...
#
#                                                lower  \
# 0                                 [smh, i, give, up]
# 1  [most, of, us, are, human, beings, but, i, thi...
# 2  [old, dirty, tricks, trump, at, it, againlike,...
# 3  [seriously, i, worked, 86, hours, my, last, ch...
# 4  [may, almighty, allah, have, mercy, on, us, al...
#
#                                    stopwords_removed  \
# 0                                        [smh, give]
# 1     [us, human, beings, think, miss, boat, george]
# 2  [old, dirty, tricks, trump, againlike, dont, k...
# 3  [seriously, worked, 86, hours, last, check, ’,...
# 4  [may, almighty, allah, mercy, us, lagosians, o...
#
#                                             pos_tags  \
# 0                          [(smh, NNS), (give, VBP)]
# 1  [(us, PRP), (human, JJ), (beings, NNS), (think...
# 2  [(old, JJ), (dirty, NN), (tricks, NNS), (trump...
# 3  [(seriously, RB), (worked, VBD), (86, CD), (ho...
# 4  [(may, MD), (almighty, VB), (allah, NN), (merc...
#
#                                          wordnet_pos
# 0                              [(smh, n), (give, v)]
# 1  [(us, n), (human, a), (beings, n), (think, v),...
# 2  [(old, a), (dirty, n), (tricks, n), (trump, v)...
# 3  [(seriously, r), (worked, v), (86, n), (hours,...
# 4  [(may, n), (almighty, v), (allah, n), (mercy, ...

# %%
# Applying word lemmatizer.

wnl = WordNetLemmatizer()

train_clean['lemmatized'] = train_clean['wordnet_pos'].apply(
    lambda x: [wnl.lemmatize(word, tag) for word, tag in x])

train_clean['lemmatized'] = train_clean['lemmatized'].apply(
    lambda x: [word for word in x if word not in stop])

train_clean['lemma_str'] = [' '.join(map(str, l)) for l in train_clean['lemmatized']]

train_clean.head()
# Out:
#    id  retweet_count  user_verified  user_statuses_count  \
# 0   0              0              0                68460
# 1   1              0              0                  309
# 2   2              0              0                 3241
# 3   3              0              0                32327
# 4   4              0              0                  581
#
#    user_followers_count  user_friends_count  \
# 0                  1101                1226
# 1                    51                 202
# 2                  1675                2325
# 3                   667                 304
# 4                    42                 127
#
#                                                 text  \
# 0                                      Smh I give up
# 1  Most of us are Human Beings but I think you mi...
# 2  Old dirty tricks Trump at it againlike we dont...
# 3  Seriously I worked 86 hours my last check and ...
# 4  May ALMIGHTY ALLAH have mercy on us all Only l...
#
#                                            tokenized  \
# 0                                 [Smh, I, give, up]
# 1  [Most, of, us, are, Human, Beings, but, I, thi...
# 2  [Old, dirty, tricks, Trump, at, it, againlike,...
# 3  [Seriously, I, worked, 86, hours, my, last, ch...
# 4  [May, ALMIGHTY, ALLAH, have, mercy, on, us, al...
#
#                                                lower  \
# 0                                 [smh, i, give, up]
# 1  [most, of, us, are, human, beings, but, i, thi...
# 2  [old, dirty, tricks, trump, at, it, againlike,...
# 3  [seriously, i, worked, 86, hours, my, last, ch...
# 4  [may, almighty, allah, have, mercy, on, us, al...
#
#                                    stopwords_removed  \
# 0                                        [smh, give]
# 1     [us, human, beings, think, miss, boat, george]
# 2  [old, dirty, tricks, trump, againlike, dont, k...
# 3  [seriously, worked, 86, hours, last, check, ’,...
# 4  [may, almighty, allah, mercy, us, lagosians, o...
#
#                                             pos_tags  \
# 0                          [(smh, NNS), (give, VBP)]
# 1  [(us, PRP), (human, JJ), (beings, NNS), (think...
# 2  [(old, JJ), (dirty, NN), (tricks, NNS), (trump...
# 3  [(seriously, RB), (worked, VBD), (86, CD), (ho...
# 4  [(may, MD), (almighty, VB), (allah, NN), (merc...
#
#                                          wordnet_pos  \
# 0                              [(smh, n), (give, v)]
# 1  [(us, n), (human, a), (beings, n), (think, v),...
# 2  [(old, a), (dirty, n), (tricks, n), (trump, v)...
# 3  [(seriously, r), (worked, v), (86, n), (hours,...
# 4  [(may, n), (almighty, v), (allah, n), (mercy, ...
#
#                                           lemmatized  \
# 0                                        [smh, give]
# 1              [u, human, think, miss, boat, george]
# 2  [old, dirty, trick, trump, againlike, dont, kn...
# 3  [seriously, work, 86, hour, last, check, ’, ev...
# 4  [may, almighty, allah, mercy, u, lagosians, ob...
#
#                                            lemma_str
# 0                                           smh give
# 1                     u human think miss boat george
# 2  old dirty trick trump againlike dont know fauc...
# 3  seriously work 86 hour last check ’ even come ...
# 4  may almighty allah mercy u lagosians observed ...

# %%
#Convert boolean variables into int (Verified/Non-verified account)
train_clean["user_verified"] = train_clean["user_verified"].astype(int)

# %%
counter_user_text = train['text'].isnull().sum()
counter_user_mentions = train['user_mentions'].isnull().sum()
counter_urls = train['urls'].isnull().sum()
counter_hashtags = train['hashtags'].isnull().sum()

# %%
print("\t Text column NULL entries: ", counter_user_text)
print("\t User_mentions column NULL entries: ", counter_user_mentions)
print("\t Urls column column NULL entries: ", counter_urls)
print("\t Hashtags column NULL entries: ", counter_hashtags)
print("\t Number of row: ", len(train_clean.index))
# Out:
# 	 Text column NULL entries:  0
# 	 User_mentions column NULL entries:  611486
# 	 Urls column column NULL entries:  451697
# 	 Hashtags column NULL entries:  593326
# 	 Number of row:  665777

# %%
#train_clean.drop('timestamp', axis=1, inplace=True)
#train_clean.drop('user_mentions', axis=1, inplace=True)
#train_clean.drop('urls', axis=1, inplace=True)
#train_clean.drop('hashtags', axis=1, inplace=True)

# %%
import pickle 

pickle_out = open("/content/gdrive/MyDrive/DataSets/covid-19/X.pickle", "wb")
pickle.dump(train_clean, pickle_out)
pickle_out.close()

# %%
import pickle 

pickle_in = open("/content/gdrive/MyDrive/DataSets/covid-19/X.pickle", "rb")
X = pickle.load(pickle_in)

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Data Visualization
#
# Our text is ready for inspection, clean and in order. We can start visualizing the data to see if we can get some insights from the tweets.
#
# > - Intuitions we would like to investigate:
# >> - We know that verified persons on twitter are politicians, govenors, and start, and are those who tweet mostly a lot and has a lot of followers, which might lead that their tweets get re-tweeted a lot.
# >> - Thoughout, this section we would like to investigate that given the dataset we have.
# >> - In order to see, what are the most discussed subjects, and used words in their tweets

# %%
# For customizing our plots.

from matplotlib.ticker import MaxNLocator
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

train_clean['Character Count'] = train_clean['text'].apply(lambda x: len(str(x)))


def plot_dist3(df, feature, title):
    # Creating a customized chart. and giving in figsize and everything.
    fig = plt.figure(constrained_layout=True, figsize=(18, 8))
    # Creating a grid of 3 cols and 3 rows.
    grid = gridspec.GridSpec(ncols=3, nrows=3, figure=fig)

    # Customizing the histogram grid.
    ax1 = fig.add_subplot(grid[0, :2])
    # Set the title.
    ax1.set_title('Histogram')
    # plot the histogram.
    sns.distplot(df.loc[:, feature],
                 hist=True,
                 kde=True,
                 ax=ax1,
                 color='#e74c3c')
    ax1.set(ylabel='Frequency')
    ax1.xaxis.set_major_locator(MaxNLocator(nbins=20))

    # Customizing the ecdf_plot.
    ax2 = fig.add_subplot(grid[1, :2])
    # Set the title.
    ax2.set_title('Empirical CDF')
    # Plotting the ecdf_Plot.
    sns.distplot(df.loc[:, feature],
                 ax=ax2,
                 kde_kws={'cumulative': True},
                 hist_kws={'cumulative': True},
                 color='#e74c3c')
    ax2.xaxis.set_major_locator(MaxNLocator(nbins=20))
    ax2.set(ylabel='Cumulative Probability')

    # Customizing the Box Plot.
    ax3 = fig.add_subplot(grid[:, 2])
    # Set title.
    ax3.set_title('Box Plot')
    # Plotting the box plot.
    sns.boxplot(x=feature, data=df, orient='v', ax=ax3, color='#e74c3c')
    ax3.yaxis.set_major_locator(MaxNLocator(nbins=25))

    plt.suptitle(f'{title}', fontsize=24)

# %%
plot_dist3(train_clean[train_clean['user_verified'] == 0], 'Character Count',
           'Characters Per "no-verified" Tweeter')

# %%
plot_dist3(train_clean[train_clean['user_verified'] == 1], 'Character Count',
           'Characters Per "Verified" tweeter')

# %%
def plot_word_number_histogram(textno, textye):
    
    """A function for comparing word counts"""

    fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(18, 6), sharey=True)
    sns.distplot(textno.str.split().map(lambda x: len(x)), ax=axes[0], color='#e74c3c')
    sns.distplot(textye.str.split().map(lambda x: len(x)), ax=axes[1], color='#e74c3c')
    
    axes[0].set_xlabel('Word Count')
    axes[0].set_ylabel('Frequency')
    axes[0].set_title('Non-Verified Tweeter')
    axes[1].set_xlabel('Word Count')
    axes[1].set_title('Verified Tweeter')
    
    fig.suptitle('Words Per Tweet', fontsize=24, va='baseline')
    
    fig.tight_layout()

# %%
plot_word_number_histogram(train_clean[train_clean['user_verified'] == 0]['text'],
                           train_clean[train_clean['user_verified'] == 1]['text'])

# %%
lis = [
    train_clean[train_clean['user_verified'] == 0]['lemma_str'],
    train_clean[train_clean['user_verified'] == 1]['lemma_str']
]

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8))
axes = axes.flatten()

for i, j in zip(lis, axes):
    try:
        new = i.str.split()
        new = new.values.tolist()
        corpus = [word.lower() for i in new for word in i]
        dic = defaultdict(int)
        for word in corpus:
            if word in stop:
                dic[word] += 1

        top = sorted(dic.items(), key=lambda x: x[1], reverse=True)[:15]
        x, y = zip(*top)
        df = pd.DataFrame([x, y]).T
        df = df.rename(columns={0: 'Stopword', 1: 'Count'})
        sns.barplot(x='Count', y='Stopword', data=df, palette='plasma', ax=j)
        plt.tight_layout()
    except:
        plt.close()
        print('No stopwords left in texts.')
        break
# Out:
# No stopwords left in texts.

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 8))
axes = axes.flatten()

for i, j in zip(lis, axes):

    new = i.str.split()
    new = new.values.tolist()
    corpus = [word for i in new for word in i]

    counter = Counter(corpus)
    most = counter.most_common()
    x, y = [], []
    for word, count in most[:30]:
        if (word not in stop):
            x.append(word)
            y.append(count)

    sns.barplot(x=y, y=x, palette='plasma', ax=j)
axes[0].set_title('Non-verified Tweeter')
axes[1].set_title('Verified Tweeter')
axes[0].set_xlabel('Count')
axes[0].set_ylabel('Word')
axes[1].set_xlabel('Count')
axes[1].set_ylabel('Word')

fig.suptitle('Most Common Unigrams', fontsize=24, va='baseline')
plt.tight_layout()

# %%
def ngrams(n, title):
    """A Function to plot most common ngrams"""
    fig, axes = plt.subplots(1, 2, figsize=(18, 8))
    axes = axes.flatten()
    for i, j in zip(lis, axes):

        new = i.str.split()
        new = new.values.tolist()
        corpus = [word for i in new for word in i]

        def _get_top_ngram(corpus, n=None):
            #getting top ngrams
            vec = CountVectorizer(ngram_range=(n, n),
                                  max_df=0.9,
                                  stop_words='english').fit(corpus)
            bag_of_words = vec.transform(corpus)
            sum_words = bag_of_words.sum(axis=0)
            words_freq = [(word, sum_words[0, idx])
                          for word, idx in vec.vocabulary_.items()]
            words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)
            return words_freq[:15]

        top_n_bigrams = _get_top_ngram(i, n)[:15]
        x, y = map(list, zip(*top_n_bigrams))
        sns.barplot(x=y, y=x, palette='plasma', ax=j)
        
        axes[1].set_title('Verified Tweeter')
        axes[0].set_title('Non-verified Tweeter')
        axes[0].set_xlabel('Count')
        axes[0].set_ylabel('Words')
        axes[1].set_xlabel('Count')
        axes[1].set_ylabel('Words')
        fig.suptitle(title, fontsize=24, va='baseline')
        plt.tight_layout()

# %%
ngrams(2, 'Most Common Bigrams')

# %%
ngrams(3, 'Most Common Trigrams')
